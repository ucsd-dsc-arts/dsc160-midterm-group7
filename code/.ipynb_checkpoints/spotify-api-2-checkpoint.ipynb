# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import api

import importlib
importlib.reload(api)
import urllib.request
import librosa
import os

cid = '5c3d73b1e0734983aec11219f14fef4f'
secret = 'f23dddb03f9a4097887e4a251758f86d'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
## 30 second samples and cover art for the top 10 tracks for Led Zeppelin:

# %%
name = 'Nas'
results = sp.search(q='artist:' + name, type='track')
items = results['tracks']['items']

# %%
albums = api.show_artist_albums(artist)

# %%
tracks_ = api.get_tracks_from_album(albums[0])

# %%
artist_name = '2PAC'
## Gets artist 
artist = api.get_artist(artist_name)

api.show_artist(artist)
# Out:
# Name  2Pac
# Popularity: 81
# Genres: ['g funk', 'gangster rap', 'hip hop', 'rap', 'west coast rap']

# %%
albums = api.show_artist_albums(artist)


tracks_ = api.get_tracks_from_album(albums[0])

# %%
tracks = api.top_songs(artist)

# %%
for i in tracks_:
        api.download_track(i, 'test_dir')

# %%
analysis = sp.audio_analysis(ids[2])
analysis.keys()
# Out:
# dict_keys(['meta', 'track', 'bars', 'beats', 'sections', 'segments', 'tatums'])

# %%
analysis['tatums']
# Out:
# [{'start': 0.63503, 'duration': 0.3669, 'confidence': 0.981},
#  {'start': 1.00193, 'duration': 0.3669, 'confidence': 0.981},
#  {'start': 1.36883, 'duration': 0.36808, 'confidence': 0.77},
#  {'start': 1.73691, 'duration': 0.36808, 'confidence': 0.77},
#  {'start': 2.10499, 'duration': 0.36252, 'confidence': 0.571},
#  {'start': 2.46751, 'duration': 0.36252, 'confidence': 0.571},
#  {'start': 2.83004, 'duration': 0.36395, 'confidence': 0.295},
#  {'start': 3.19398, 'duration': 0.36395, 'confidence': 0.295},
#  {'start': 3.55793, 'duration': 0.36462, 'confidence': 0.377},
#  {'start': 3.92255, 'duration': 0.36462, 'confidence': 0.377},
#  {'start': 4.28717, 'duration': 0.36015, 'confidence': 0.254},
#  {'start': 4.64732, 'duration': 0.36015, 'confidence': 0.254},
#  {'start': 5.00747, 'duration': 0.35536, 'confidence': 0.404},
#  {'start': 5.36283, 'duration': 0.35536, 'confidence': 0.404},
#  {'start': 5.71819, 'duration': 0.357, 'confidence': 0.306},
# ...

# %%
features = sp.audio_features(['2Wod0L2okNpxB8CbYWwgtv'])
features
# Out:
# [{'danceability': 0.782,
#   'energy': 0.543,
#   'key': 7,
#   'loudness': -7.861,
#   'mode': 1,
#   'speechiness': 0.0595,
#   'acousticness': 0.0355,
#   'instrumentalness': 0,
#   'liveness': 0.148,
#   'valence': 0.403,
#   'tempo': 105.011,
#   'type': 'audio_features',
#   'id': '2Wod0L2okNpxB8CbYWwgtv',
#   'uri': 'spotify:track:2Wod0L2okNpxB8CbYWwgtv',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Wod0L2okNpxB8CbYWwgtv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Wod0L2okNpxB8CbYWwgtv',
#   'duration_ms': 228179,
#   'time_signature': 4}]

# %%
r = sp.artist_top_tracks(drake['id'])

# %%
r['tracks'][0]['id']
# Out:
# '2D2pqz9UjxOsLbucKFAHTV'

# %%
sp.tracks(['5k0rH5wWg40mlDHBkhhJPv'])['tracks'][0]['album']

# %%
#r['tracks'][3]

# %%
show_recommendations_for_artist(drake)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-25e25e35f3ee> in <module>
#       5                     track['artists'][0]['name'])
#       6     return results
# ----> 7 show_recommendations_for_artist('higher brothers')
#
# <ipython-input-40-25e25e35f3ee> in show_recommendations_for_artist(artist)
#       1 def show_recommendations_for_artist(artist):
# ----> 2     results = sp.recommendations(seed_artists=[artist['id']])
#       3     for track in results['tracks']:
#       4         print('Recommendation: %s - %s', track['name'],
#       5                     track['artists'][0]['name'])
#
# TypeError: string indices must be integers

# %%
def show_artist_albums(artist):
    albums = []
    results = sp.artist_albums(artist['id'], album_type='album')
    albums.extend(results['items'])
    while results['next']:
        results = sp.next(results)
        albums.extend(results['items'])
    seen = set()  # to avoid dups
    albums.sort(key=lambda album: album['name'].lower())
    for album in albums:
        name = album['name']
        if name not in seen:
            print('ALBUM: %s', name)
            seen.add(name)
    return seen
show_artist_albums(drake)
# Out:
# ALBUM: %s Care Package
# ALBUM: %s If You're Reading This It's Too Late
# ALBUM: %s More Life
# ALBUM: %s Nothing Was The Same
# ALBUM: %s Nothing Was The Same (Deluxe)
# ALBUM: %s Scorpion
# ALBUM: %s So Far Gone
# ALBUM: %s Take Care
# ALBUM: %s Take Care (Deluxe)
# ALBUM: %s Take Care (Explicit Deluxe)
# ALBUM: %s Thank Me Later
# ALBUM: %s Thank Me Later (Int'l Version)
# ALBUM: %s Views
# ALBUM: %s What A Time To Be Alive
# {'Care Package',
#  "If You're Reading This It's Too Late",
#  'More Life',
#  'Nothing Was The Same',
#  'Nothing Was The Same (Deluxe)',
#  'Scorpion',
#  'So Far Gone',
#  'Take Care',
#  'Take Care (Deluxe)',
#  'Take Care (Explicit Deluxe)',
#  'Thank Me Later',
#  "Thank Me Later (Int'l Version)",
#  'Views',
#  'What A Time To Be Alive'}

# %%
def show_artist(artist):
    print('====%s====', artist['name'])
    print('Popularity: %s', artist['popularity'])
    if len(artist['genres']) > 0:
        print('Genres: %s', ','.join(artist['genres']))
show_artist(drake)
# Out:
# ====%s==== Drake
# Popularity: %s 98
# Genres: %s canadian hip hop,canadian pop,hip hop,pop rap,rap,toronto rap

# %%
playlist_id = 'spotify:user:spotifycharts:playlist:37i9dQZF1DX9sQDbOMReFI'
results = sp.playlist(playlist_id)

# %%
results['tracks']['items'][0]['track']['name']
# Out:
# 'Nuthin\' But A "G" Thang'
